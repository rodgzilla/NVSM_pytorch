# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchtext
from torch.utils.data import TensorDataset
from torch.utils.data import random_split
from torch.utils.data import DataLoader

import torch.optim as optim

import spacy

# %% [markdown]
# # NVSM model

# %%
class NVSM(nn.Module):
    def __init__(self, n_doc, n_tok, dim_doc_emb, dim_tok_emb, neg_sampling_rate, 
                 pad_token_id):
        super(NVSM, self).__init__()
        self.doc_emb           = nn.Embedding(n_doc, embedding_dim = dim_doc_emb)
        self.tok_emb           = nn.Embedding(n_tok, embedding_dim = dim_tok_emb)
        self.tok_to_doc        = nn.Linear(dim_tok_emb, dim_doc_emb)
        self.bias              = nn.Parameter(torch.Tensor(dim_doc_emb))
        self.neg_sampling_rate = neg_sampling_rate
        self.pad_token_id      = pad_token_id
        
    def query_to_tensor(self, query):
        '''
        Computes the average of the word embeddings of the query. This method 
        corresponds to the function 'g' in the article.
        '''
        # Create a mask to ignore padding embeddings
        query_mask    = (query != self.pad_token_id).float()
        # Compute the number of tokens in each query to properly compute the 
        # average
        tok_by_input  = query_mask.sum(dim = 1)
        query_tok_emb = self.tok_emb(query)
        query_tok_emb = query_tok_emb * query_mask.unsqueeze(-1)
        # Compute the average of the embeddings
        query_emb     = query_tok_emb.sum(dim = 1) / tok_by_input.unsqueeze(-1)
        
        return query_emb
    
    def normalize_query_tensor(self, query_tensor):
        '''
        Divides each query tensor by its L2 norm. This method corresponds to 
        the function 'norm' in the article.
        '''
        norm = torch.norm(query_tensor, dim = 1) # we might have to detach this value 
                                                 # from the computation graph.
        return query_tensor / norm.unsqueeze(-1)
        
    def query_to_doc_space(self, query):
        '''
        Projects a query vector into the document vector space. This method corresponds 
        to the function 'f' in the article.
        '''
        return self.tok_to_doc(query)
    
    def score(self, query, document):
        '''
        Computes the cosine similarity between a query and a document embedding.
        This method corresponds to the function 'score' in the article.
        '''
        # batch dot product using batch matrix multiplication
        num   = torch.bmm(query.unsqueeze(1), document.unsqueeze(-1))
        denum = torch.norm(query, dim = 1) * torch.norm(document, dim = 1)
        
        return num / denum
        
    def non_stand_projection(self, n_gram):
        '''
        Computes the non-standard projection of a n-gram into the document vector 
        space. This method corresponds to the function 'T^~' in the article.
        '''
        n_gram_tensor      = self.query_to_tensor(n_gram)
        norm_n_gram_tensor = self.normalize_query_tensor(n_gram_tensor)
        projection         = self.query_to_doc_space(norm_n_gram_tensor)
        
        return projection
    
    def _custom_batchnorm(self, batch):
        '''
        Computes the variant of the batch normalization formula used in this article. 
        It only uses a bias and no weights.
        '''
        batch_feat_norm = (batch - batch.mean(dim = 0)) / batch.std(dim = 0)
        batch_feat_norm = batch_feat_norm + self.bias
        
        return batch_feat_norm
    
    def stand_projection(self, batch):
        '''
        Computes the standard projection of a n-gram into document vector space with
        a hardtanh activation. This method corresponds to the function 'T' in the 
        article.
        '''
        non_stand_proj = self.non_stand_projection(batch) 
        bn             = self._custom_batchnorm(non_stand_proj)
        activation     = F.hardtanh(bn)

        return activation
    
    def representation_similarity(self, query, document):
        '''
        Computes the similarity between a query and a document. This method corresponds 
        to the function 'P' in the article.
        '''
        document_emb  = self.doc_emb(document)
        query_proj    = self.stand_projection(query)
        # If we have a single document to match against each query, we have
        # to reshape the tensor to compute a simple dot product.
        # Otherwise, we compute a simple matrix multiplication to match the 
        # query against each document.
        if len(document_emb.shape) == 2:
            document_emb = document_emb.unsqueeze(1)
        dot_product   = torch.bmm(document_emb, query_proj.unsqueeze(-1))
        similarity    = torch.sigmoid(dot_product)
        
        return similarity.squeeze()
    
    def forward(self, query, document):
        '''
        Approximates the probability of document given query by uniformly sampling 
        constrastive examples. This method corresponds to the 'P^~' function in the 
        article.
        '''
        # Positive term, this should be maximized as it indicates how similar the
        # correct document is to the query
        pos_repr = self.representation_similarity(query, document)
        
        # Sampling uniformly 'self.neg_sampling_rate' documents to compute the 
        # negative term. We first randomly draw the indices of the documents and 
        # then we compute the similarity with the query.
        z               = self.neg_sampling_rate # corresponds to the z variable in 
                                                 # the article
        n_docs          = self.doc_emb.num_embeddings
        neg_sample_size = (query.size(0), z)
        neg_sample      = torch.randint(low = 0, high = n_docs, size = neg_sample_size)
        neg_repr        = self.representation_similarity(query, neg_sample)
        
        # Probability computation
        positive_term = torch.log(pos_repr)
        negative_term = torch.log(1 - neg_repr).sum(dim = 1)
        proba         = ((z + 1) / (2 * z)) * (z * positive_term + negative_term)
        
        return proba

# %%
def loss_function(nvsm, pred, lamb):
    output_term = pred.mean()
    sum_square  = lambda m: (m.weight * m.weight).sum()
    reg_term    = sum_square(nvsm.tok_emb) + \
                  sum_square(nvsm.doc_emb) + \
                  sum_square(nvsm.tok_to_doc)
    loss        = -output_term + (lamb / (2 * pred.shape[0])) * reg_term
    if torch.isnan(loss):
        print('output_term', output_term)
        print('reg_term', reg_term)
    
    return loss

# %% [markdown]
# # Dataset creation

# %%
spacy_en = spacy.load('en')

def tokenize(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
def load_docs(filepaths):
    documents = []
    for filepath in filepaths:
        with open(filepath) as file:
            documents.append(file.read().strip().lower())

    return documents

# %%
def tokenize_docs(documents):
    tokenized_documents = [tokenize(doc) for doc in documents]
#     print([len(doc_tok) for doc_tok in tokenized_documents])
    
    return tokenized_documents

# %%
def create_vocabulary(tokenized_documents):
    vocabulary    = {token for doc in tokenized_documents for token in doc}
    stoi          = {token : i + 2 for i, token in enumerate(vocabulary)}
    stoi['<PAD>'] = 0
    stoi['<UNK>'] = 1
    itos          = {i : token for token, i in stoi.items()}
    
    return vocabulary, stoi, itos

# %%
def create_dataset(tok_docs, stoi, n):
    n_grams      = []
    document_ids = []
    for i, doc in enumerate(tok_docs):
        doc_tok_ids = [stoi[tok] for tok in doc]
        for n_gram in [doc_tok_ids[i : i + n] for i in range(len(doc) - n)]:
            n_grams.append(n_gram)
            document_ids.append(i)
            
    return n_grams, document_ids

# %%
def create_pytorch_datasets(n_grams, doc_ids, val_prop = 0.2):
    n_grams_tensor = torch.tensor(n_grams)
    doc_ids_tensor = torch.tensor(doc_ids)
    full_dataset   = TensorDataset(n_grams_tensor, doc_ids_tensor)
    total_size     = len(full_dataset)
    val_size       = round(total_size * val_prop)
    train, val     = random_split(full_dataset, [total_size - val_size, val_size])
    
    return train, val

# %%
def main():
    filepaths = [
        '../data/raw/language/Word_formation',
        '../data/raw/language/Terminology',    
        '../data/raw/history/Jacobin',
        '../data/raw/history/French_Revolution',
        '../data/raw/math/Game_theory',
        '../data/raw/math/Laplacian_matrix'
    ]
    documents             = load_docs(filepaths)
    tokenized_documents   = tokenize_docs(documents)
    print(len(tokenized_documents))
    voc, stoi, itos       = create_vocabulary(tokenized_documents)
    print(len(stoi))
    n_grams, document_ids = create_dataset(tokenized_documents, stoi, 10)
    train_data, val_data  = create_pytorch_datasets(n_grams, document_ids)

    return train_data, val_data
train_data, val_data = main()
# Out:
# 6
# 10811

# %%
train_loader = DataLoader(train_data, batch_size = 32, shuffle = True)

# %%
nvsm = NVSM(
    n_doc             = 6, 
    n_tok             = 10811, 
    dim_doc_emb       = 20, 
    dim_tok_emb       = 30,
    neg_sampling_rate = 4,
    pad_token_id      = 0
)

# %%
optimizer = optim.Adam(nvsm.parameters(), lr = 1e-4)
lamb      = 1e-3 # loss param
lamb      = 0 # to test if the nan comes from the regularizer

# %%
for epoch in range(10):
    for i, (n_grams, doc_ids) in enumerate(train_loader):
        optimizer.zero_grad()
        pred_proba = nvsm(n_grams, doc_ids)
        loss = loss_function(nvsm, pred_proba, lamb)
        loss.backward()
        optimizer.step()
        if i % 250 == 0:
            print(f'[{epoch},{i}]: {loss}')
# Out:
# [0,0]: 11.241998672485352
# [0,250]: 10.193885803222656
# [0,500]: 10.336831092834473
# [0,750]: 9.331047058105469
# [0,1000]: 9.37333869934082
# [0,1250]: 8.306572914123535
# [0,1500]: 9.355215072631836
# [0,1750]: 8.322171211242676
# [1,0]: 7.784219741821289
# [1,250]: 7.881677627563477
# [1,500]: 7.817204475402832
# [1,750]: 7.648210525512695
# [1,1000]: 7.4608306884765625
# [1,1250]: 7.3959856033325195
# [1,1500]: 7.394585132598877
# [1,1750]: 7.675374507904053
# [2,0]: 7.161081314086914
# [2,250]: 7.507979869842529
# [2,500]: 7.53243350982666
# [2,750]: 7.203186988830566
# [2,1000]: 7.5195722579956055
# [2,1250]: 7.234435558319092
# [2,1500]: 6.980432510375977
# [2,1750]: 7.037199974060059
# [3,0]: 7.251575469970703
# output_term tensor(-7.1915, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.9428, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.3660, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.1482, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.3130, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.3670, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.1884, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.1950, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.6224, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.6475, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.0983, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-9.0813, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.7694, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.1150, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.7930, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.2212, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.0315, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.6568, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.9976, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.1286, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.3676, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.6500, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.5039, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.8654, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.4617, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.7939, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.0505, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.2926, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.6416, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.0753, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.7172, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.8647, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.0291, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.5896, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.0954, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.2469, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.4714, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.4498, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.4407, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.8880, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.8797, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.1416, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.3735, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.6903, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.3061, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.6518, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.0401, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.9093, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.5885, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.6240, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.8317, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.4629, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.6486, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.6593, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.1307, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.0805, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.6630, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.3343, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.6220, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.1857, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.8908, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7498, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.5246, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.8699, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.7730, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-8.7676, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.6717, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2241, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.1249, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.5040, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.2166, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4733, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.3443, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.8663, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9432, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4072, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(
grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6320, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.6287, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9732, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1136, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0122, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2094, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.1207, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.3875, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.3418, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8901, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6701, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.6919, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8410, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7884, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.2811, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.9774, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8182, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.3168, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.5839, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.3595, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5932, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2213, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2023, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.1366, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3519, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5159, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1665, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.0055, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.0848, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7810, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9321, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7291, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7753, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8697, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4981, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6273, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9609, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4816, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.9553, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-7.1671, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.5130, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8693, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2730, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7217, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2989, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3042, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.9864, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# [3,500]: nan
# output_term tensor(-3.6553, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.1308, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3837, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.1659, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.5945, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0195, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2126, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5515, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2108, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1546, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2944, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0160, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4550, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3038, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4506, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4266, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6897, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.9691, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8792, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6715, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0971, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0581, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0812, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9937, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0168, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7800, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9333, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8819, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6402, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7313, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0866, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3772, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0395, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8153, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9916, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7589, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.6331, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3171, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9188, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.5738, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9276, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4821, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7826, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.3859, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8560, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0054, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2264, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0839, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0298, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.1755, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2608, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6233, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.3317, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8130, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.9674, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7840, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.5952, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9892, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6275, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0355, grad_fn=<MeanBackward1>)
# ...
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.3472, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7793, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3223, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6552, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7904, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7284, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9814, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1329, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4790, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1072, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7926, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2398, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1877, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5616, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4220, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8984, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8824, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2411, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5179, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6686, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0699, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6253, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9881, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4640, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1266, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4143, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8217, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9564, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4005, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4366, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8071, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1167, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7431, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1523, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6191, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1224, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2605, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9592, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2239, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5251, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3240, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4603, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4177, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7956, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3689, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2159, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3184, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6578, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0222, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9168, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1278, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5696, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6405, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5531, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2405, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6526, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4513, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4699, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1781, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0999, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0485, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9397, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1156, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4958, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8903, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2581, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3691, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7911, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4463, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1449, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1385, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4794, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1559, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6155, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1464, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0181, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0858, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8241, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2653, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6515, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1077, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0665, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5468, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9039, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9495, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6392, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4622, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2790, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9882, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4401, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5578, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9793, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5915, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6775, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5715, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4284, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2163, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.1629, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7840, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6283, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2556, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6474, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4231, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9271, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4618, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4746, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5982, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2430, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5890, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0338, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1932, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1772, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2642, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.7489, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7791, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9252, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6041, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8639, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7676, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4325, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8872, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9899, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8707, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8370, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2205, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4699, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2756, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1158, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7688, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1985, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5829, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3293, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4692, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1890, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9048, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6816, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2696, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4611, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6866, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6379, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4722, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7618, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2083, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8767, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9360, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1234, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9534, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5809, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5036, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1663, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4482, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9220, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8427, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0578, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-58f0564f7e64> in <module>
#       2     for i, (n_grams, doc_ids) in enumerate(train_loader):
#       3         optimizer.zero_grad()
# ----> 4         pred_proba = nvsm(n_grams, doc_ids)
#       5         loss = loss_function(nvsm, pred_proba, lamb)
#       6         loss.backward()
#
# ~/anaconda3/envs/nvsm_pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     484         for hook in self._forward_pre_hooks.values():
#     485             hook(self, input)
# --> 486         if torch._C._get_tracing_state():
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
#
# KeyboardInterrupt:
