# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchtext
from torch.utils.data import TensorDataset
from torch.utils.data import random_split
from torch.utils.data import DataLoader

import torch.optim as optim

import spacy

# %% [markdown]
# # NVSM model

# %%
class NVSM(nn.Module):
    def __init__(self, n_doc, n_tok, dim_doc_emb, dim_tok_emb, neg_sampling_rate, 
                 pad_token_id):
        super(NVSM, self).__init__()
        self.doc_emb           = nn.Embedding(n_doc, embedding_dim = dim_doc_emb)
        self.tok_emb           = nn.Embedding(n_tok, embedding_dim = dim_tok_emb)
        self.tok_to_doc        = nn.Linear(dim_tok_emb, dim_doc_emb)
        self.bias              = nn.Parameter(torch.Tensor(dim_doc_emb))
        self.neg_sampling_rate = neg_sampling_rate
        self.pad_token_id      = pad_token_id
        
    def query_to_tensor(self, query):
        '''
        Computes the average of the word embeddings of the query. This method 
        corresponds to the function 'g' in the article.
        '''
        # Create a mask to ignore padding embeddings
        query_mask    = (query != self.pad_token_id).float()
        # Compute the number of tokens in each query to properly compute the 
        # average
        tok_by_input  = query_mask.sum(dim = 1)
        query_tok_emb = self.tok_emb(query)
        query_tok_emb = query_tok_emb * query_mask.unsqueeze(-1)
        # Compute the average of the embeddings
        query_emb     = query_tok_emb.sum(dim = 1) / tok_by_input.unsqueeze(-1)
        
        return query_emb
    
    def normalize_query_tensor(self, query_tensor):
        '''
        Divides each query tensor by its L2 norm. This method corresponds to 
        the function 'norm' in the article.
        '''
        norm = torch.norm(query_tensor, dim = 1) # we might have to detach this value 
                                                 # from the computation graph.
        return query_tensor / norm.unsqueeze(-1)
        
    def query_to_doc_space(self, query):
        '''
        Projects a query vector into the document vector space. This method corresponds 
        to the function 'f' in the article.
        '''
        return self.tok_to_doc(query)
    
    def score(self, query, document):
        '''
        Computes the cosine similarity between a query and a document embedding.
        This method corresponds to the function 'score' in the article.
        '''
        # batch dot product using batch matrix multiplication
        num   = torch.bmm(query.unsqueeze(1), document.unsqueeze(-1))
        denum = torch.norm(query, dim = 1) * torch.norm(document, dim = 1)
        
        return num / denum
        
    def non_stand_projection(self, n_gram):
        '''
        Computes the non-standard projection of a n-gram into the document vector 
        space. This method corresponds to the function 'T^~' in the article.
        '''
        n_gram_tensor      = self.query_to_tensor(n_gram)
        norm_n_gram_tensor = self.normalize_query_tensor(n_gram_tensor)
        projection         = self.query_to_doc_space(norm_n_gram_tensor)
        
        return projection
    
    def _custom_batchnorm(self, batch):
        '''
        Computes the variant of the batch normalization formula used in this article. 
        It only uses a bias and no weights.
        '''
        batch_feat_norm = (batch - batch.mean(dim = 0)) / batch.std(dim = 0)
        batch_feat_norm = batch_feat_norm + self.bias
        
        return batch_feat_norm
    
    def stand_projection(self, batch):
        '''
        Computes the standard projection of a n-gram into document vector space with
        a hardtanh activation. This method corresponds to the function 'T' in the 
        article.
        '''
        non_stand_proj = self.non_stand_projection(batch) 
        bn             = self._custom_batchnorm(non_stand_proj)
        activation     = F.hardtanh(bn)

        return activation
    
    def representation_similarity(self, query, document):
        '''
        Computes the similarity between a query and a document. This method corresponds 
        to the function 'P' in the article.
        '''
        document_emb  = self.doc_emb(document)
        query_proj    = self.stand_projection(query)
        # If we have a single document to match against each query, we have
        # to reshape the tensor to compute a simple dot product.
        # Otherwise, we compute a simple matrix multiplication to match the 
        # query against each document.
        if len(document_emb.shape) == 2:
            document_emb = document_emb.unsqueeze(1)
        dot_product   = torch.bmm(document_emb, query_proj.unsqueeze(-1))
        similarity    = torch.sigmoid(dot_product)
        
        return similarity.squeeze()
    
    def forward(self, query, document):
        '''
        Approximates the probability of document given query by uniformly sampling 
        constrastive examples. This method corresponds to the 'P^~' function in the 
        article.
        '''
        # Positive term, this should be maximized as it indicates how similar the
        # correct document is to the query
        pos_repr = self.representation_similarity(query, document)
        
        # Sampling uniformly 'self.neg_sampling_rate' documents to compute the 
        # negative term. We first randomly draw the indices of the documents and 
        # then we compute the similarity with the query.
        z               = self.neg_sampling_rate # corresponds to the z variable in 
                                                 # the article
        n_docs          = self.doc_emb.num_embeddings
        neg_sample_size = (query.size(0), z)
        neg_sample      = torch.randint(low = 0, high = n_docs, size = neg_sample_size)
        neg_repr        = self.representation_similarity(query, neg_sample)
        
        # Probability computation
        positive_term = torch.log(pos_repr)
        negative_term = torch.log(1 - neg_repr).sum(dim = 1)
        proba         = ((z + 1) / (2 * z)) * (z * positive_term + negative_term)
        
        return proba

# %%
def loss_function(nvsm, pred, lamb):
    output_term = pred.mean()
    sum_square  = lambda m: (m.weight * m.weight).sum()
    reg_term    = sum_square(nvsm.tok_emb) + \
                  sum_square(nvsm.doc_emb) + \
                  sum_square(nvsm.tok_to_doc)
    loss        = -output_term + (lamb / (2 * pred.shape[0])) * reg_term
    if torch.isnan(loss):
        print('output_term', output_term)
        print('reg_term', reg_term)
    
    return loss

# %% [markdown]
# # Dataset creation

# %%
spacy_en = spacy.load('en')

def tokenize(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
def load_docs(filepaths):
    documents = []
    for filepath in filepaths:
        with open(filepath) as file:
            documents.append(file.read().strip().lower())

    return documents

# %%
def tokenize_docs(documents):
    tokenized_documents = [tokenize(doc) for doc in documents]
#     print([len(doc_tok) for doc_tok in tokenized_documents])
    
    return tokenized_documents

# %%
def create_vocabulary(tokenized_documents):
    vocabulary    = {token for doc in tokenized_documents for token in doc}
    stoi          = {token : i + 2 for i, token in enumerate(vocabulary)}
    stoi['<PAD>'] = 0
    stoi['<UNK>'] = 1
    itos          = {i : token for token, i in stoi.items()}
    
    return vocabulary, stoi, itos

# %%
def create_dataset(tok_docs, stoi, n):
    n_grams      = []
    document_ids = []
    for i, doc in enumerate(tok_docs):
        doc_tok_ids = [stoi[tok] for tok in doc]
        for n_gram in [doc_tok_ids[i : i + n] for i in range(len(doc) - n)]:
            n_grams.append(n_gram)
            document_ids.append(i)
            
    return n_grams, document_ids

# %%
def create_pytorch_datasets(n_grams, doc_ids, val_prop = 0.2):
    n_grams_tensor = torch.tensor(n_grams)
    doc_ids_tensor = torch.tensor(doc_ids)
    full_dataset   = TensorDataset(n_grams_tensor, doc_ids_tensor)
    total_size     = len(full_dataset)
    val_size       = round(total_size * val_prop)
    train, val     = random_split(full_dataset, [total_size - val_size, val_size])
    
    return train, val

# %%
def main():
    filepaths = [
        '../data/raw/language/Word_formation',
        '../data/raw/language/Terminology',    
        '../data/raw/history/Jacobin',
        '../data/raw/history/French_Revolution',
        '../data/raw/math/Game_theory',
        '../data/raw/math/Laplacian_matrix'
    ]
    documents             = load_docs(filepaths)
    tokenized_documents   = tokenize_docs(documents)
    print(len(tokenized_documents))
    voc, stoi, itos       = create_vocabulary(tokenized_documents)
    print(len(stoi))
    n_grams, document_ids = create_dataset(tokenized_documents, stoi, 10)
    train_data, val_data  = create_pytorch_datasets(n_grams, document_ids)

    return train_data, val_data
train_data, val_data = main()
# Out:
# 6
# 10811

# %%
train_loader = DataLoader(train_data, batch_size = 32, shuffle = True)

# %%
nvsm = NVSM(
    n_doc             = 6, 
    n_tok             = 10811, 
    dim_doc_emb       = 20, 
    dim_tok_emb       = 30,
    neg_sampling_rate = 4,
    pad_token_id      = 0
)

# %%
optimizer = optim.Adam(nvsm.parameters())
lamb      = 1e-3 # loss param

# %%
for i, (n_grams, doc_ids) in enumerate(train_loader):
    optimizer.zero_grad()
    pred_proba = nvsm(n_grams, doc_ids)
    loss = loss_function(nvsm, pred_proba, lamb)
    loss.backward()
    optimizer.step()
    if i % 25 == 0:
        print(f'Step [{i}]: {loss}')
# Out:
# Step [0]: 12.357385635375977
# Step [25]: 10.593009948730469
# Step [50]: 8.918313980102539
# Step [75]: 8.135411262512207
# Step [100]: 8.731405258178711
# Step [125]: 8.549154281616211
# Step [150]: 7.6804938316345215
# Step [175]: 7.904236316680908
# Step [200]: 7.862060070037842
# Step [225]: 7.385550498962402
# Step [250]: 7.006918907165527
# Step [275]: 7.4187774658203125
# Step [300]: 7.37831974029541
# Step [325]: 7.254450798034668
# Step [350]: 8.218130111694336
# Step [375]: 7.680710315704346
# Step [400]: 6.760675430297852
# Step [425]: 6.504920959472656
# Step [450]: 7.498491287231445
# Step [475]: 6.883847713470459
# Step [500]: 6.688193321228027
# Step [525]: 7.059329509735107
# Step [550]: 6.972996234893799
# Step [575]: 6.514847755432129
# Step [600]: 6.2320780754089355
# Step [625]: 6.176499366760254
# Step [650]: 6.146053791046143
# Step [675]: 7.046422958374023
# Step [700]: 6.39678955078125
# Step [725]: 6.097646713256836
# Step [750]: 6.331378936767578
# Step [775]: 6.6683268547058105
# Step [800]: 6.0362548828125
# Step [825]: 6.293006420135498
# Step [850]: 6.283914566040039
# output_term tensor(-5.8361, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-6.1541, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7499, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.4329, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7419, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.7403, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6860, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8052, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9878, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.8595, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [875]: nan
# output_term tensor(-5.4227, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.5244, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5531, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0133, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.5438, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6615, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4212, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5665, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.4953, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.9015, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.5812, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6556, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7928, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.2382, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7467, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.0288, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0765, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9309, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.1468, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5603, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3252, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7144, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0801, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.6925, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.8555, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [900]: nan
# output_term tensor(-3.5823, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3669, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3572, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0417, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5639, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6618, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6182, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-5.1430, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1174, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9654, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.2814, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0466, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0200, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0087, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2856, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3334, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.9389, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2454, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9187, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5192, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6926, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0882, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7343, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5214, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9191, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [925]: nan
# output_term tensor(-3.5149, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5888, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1789, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3540, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9369, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5393, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5686, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8128, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6020, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5557, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3619, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7154, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5012, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4856, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8441, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6447, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7357, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9716, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9420, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3085, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4248, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5028, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5021, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7571, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6362, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [950]: nan
# output_term tensor(-2.7869, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4836, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3878, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6867, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9784, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4632, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8531, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8843, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9916, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3457, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8115, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5485, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6455, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5117, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6134, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6548, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7500, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1349, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6572, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2657, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5578, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3625, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4528, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2721, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6321, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [975]: nan
# output_term tensor(-2.7705, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3892, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5216, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9846, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6109, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2951, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0965, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7919, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5545, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9237, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.2961, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7405, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1582, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7076, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5296, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5625, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5235, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8218, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6740, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2058, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6943, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7330, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6636, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7818, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6978, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1000]: nan
# output_term tensor(-2.9542, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8156, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6853, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5951, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9217, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3781, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7071, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9261, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8081, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4988, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2129, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6822, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9158, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9781, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6782, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3388, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5219, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4961, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7138, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9639, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5638, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0277, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5347, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8945, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3770, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1025]: nan
# output_term tensor(-3.1757, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7019, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8961, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7145, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8602, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5528, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5737, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8352, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4151, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9543, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8945, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9597, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7115, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8825, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4053, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0629, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5756, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6563, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.3570, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6477, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5267, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4309, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8851, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3637, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1342, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1050]: nan
# output_term tensor(-3.3883, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7128, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6573, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6589, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4703, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9255, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4135, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5778, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5948, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7039, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6396, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9234, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4429, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5059, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8009, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9434, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1767, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5419, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7878, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3447, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5832, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8681, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2177, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6292, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5976, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1075]: nan
# output_term tensor(-2.9740, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7892, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8384, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5257, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8928, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5269, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7808, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8233, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6923, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8291, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7344, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6134, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5364, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3029, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.6083, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6102, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9611, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7356, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7682, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6837, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8355, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5069, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7351, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4316, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5231, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1100]: nan
# output_term tensor(-3.5026, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9398, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5903, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6823, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.1900, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4646, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4830, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6304, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6124, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4585, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9096, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6380, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6813, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9406, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.2707, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2375, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5896, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4558, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7179, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7934, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6995, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3929, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2798, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0640, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4566, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1125]: nan
# output_term tensor(-2.4854, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0863, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8532, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3766, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7203, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7562, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5032, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1665, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3968, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5481, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0515, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2418, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6524, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0973, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3659, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4685, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5801, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2397, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5626, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0410, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9501, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6091, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3295, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7172, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4658, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1150]: nan
# output_term tensor(-2.9952, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4346, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5677, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5812, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1943, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7585, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0500, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5032, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5790, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3780, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6950, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4537, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4523, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5708, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7738, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9178, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0513, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9560, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9513, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6427, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7015, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6858, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1630, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3446, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4122, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1175]: nan
# output_term tensor(-2.7542, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7500, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5913, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0651, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9063, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4754, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6781, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7219, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3710, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9027, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1299, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0316, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8868, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8745, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4523, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7321, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6048, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6667, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0200, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0812, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5853, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6285, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3644, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6993, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9274, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1200]: nan
# output_term tensor(-2.4900, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7170, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8413, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8544, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6075, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5254, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7037, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6365, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9126, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3133, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3775, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6381, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5923, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6538, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5960, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8680, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6210, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2568, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5828, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6827, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7986, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7091, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1097, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5397, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6946, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1225]: nan
# output_term tensor(-2.9730, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7129, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4564, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4028, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5673, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6411, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-4.0415, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6234, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5710, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8782, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5330, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5743, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8358, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9866, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5388, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6385, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0242, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9072, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1939, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1866, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4191, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8995, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0811, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4975, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7590, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1250]: nan
# output_term tensor(-2.8124, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8149, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8978, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6388, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2499, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7150, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5673, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9536, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6132, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2069, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6641, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2945, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5726, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3872, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6851, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4078, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7615, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6184, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4660, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1582, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8359, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6432, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.2783, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7499, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7496, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1275]: nan
# output_term tensor(-3.0654, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5588, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8128, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7207, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8792, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7649, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.7518, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4826, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5339, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0994, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0709, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3608, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6273, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4641, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8581, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1542, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7549, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0874, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9776, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5819, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9038, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0413, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2053, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4262, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6060, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1300]: nan
# output_term tensor(-2.7796, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.8505, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7909, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0744, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9785, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4351, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8315, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9031, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7557, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7164, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0828, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3745, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1398, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5176, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4635, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7632, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6631, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7033, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9745, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0611, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9424, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8894, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4789, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5956, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8608, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1325]: nan
# output_term tensor(-2.8005, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5900, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5772, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8486, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.5376, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.2938, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1580, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6403, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7961, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7235, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0612, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9443, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9202, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7238, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1838, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7535, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6456, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7351, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5468, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6627, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9963, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8058, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0451, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7803, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7313, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1350]: nan
# output_term tensor(-2.7815, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0317, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9120, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8085, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2303, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7453, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4639, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5779, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8106, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9926, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8561, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9355, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0147, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9908, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1379, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9100, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4403, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9627, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7297, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6689, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9484, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9291, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1011, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6732, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7198, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1375]: nan
# output_term tensor(-2.7675, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6044, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8357, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4882, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4352, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8447, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2427, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9807, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9937, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2483, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8077, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8710, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5012, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7618, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0011, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6501, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.2283, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6147, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6098, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0491, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6871, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7700, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6898, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.0157, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9899, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1400]: nan
# output_term tensor(-2.5190, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7284, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5852, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5727, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8819, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7310, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2084, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9919, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5028, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6804, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4976, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5903, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7175, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1209, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9416, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4986, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7682, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.4033, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3311, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8234, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9169, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8382, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.2667, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2017, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3880, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# Step [1425]: nan
# output_term tensor(-2.5008, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6793, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6380, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5510, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.2565, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.4031, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7490, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6761, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1326, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8228, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8530, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8741, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6971, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6318, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.5357, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.3878, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.6774, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.7335, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9719, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.9165, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-2.8762, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.3436, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# output_term tensor(-3.1799, grad_fn=<MeanBackward1>)
# reg_term tensor(nan, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-88bc0dfefd92> in <module>
#       3     pred_proba = nvsm(n_grams, doc_ids)
#       4     loss = loss_function(nvsm, pred_proba, lamb)
# ----> 5     loss.backward()
#       6     optimizer.step()
#       7     if i % 25 == 0:
#
# ~/anaconda3/envs/nvsm_pytorch/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/anaconda3/envs/nvsm_pytorch/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
torch.isnan?

# %%
# query = torch.tensor([
#     [1, 2, 3, 0, 0], 
#     [4, 5, 6, 7, 8],
#     [2, 7, 8, 3, 0]
# ])
# document = torch.tensor([2,3,7])
# print(query)
# print(document)

# %%
# for i in range(500):
#     optimizer.zero_grad()
#     pred_proba = nvsm(query, document)
#     loss = loss_function(nvsm, pred_proba, lamb)
#     loss.backward()
#     optimizer.step()
#     if i % 25 == 0:
#         print(f'Step [{i}]: {loss}')
