# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import mplcursors

# %%
np.random.seed(42)

fig, ax = plt.subplots()
ax.scatter(*np.random.random((2, 26)))
ax.set_title("Mouse over a point")

mplcursors.cursor(hover=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
lines = ax.plot(range(3), range(3), "o")
labels = ["a", "b", "c"]
cursor = mplcursors.cursor(lines)
cursor.connect(
    "add", lambda sel: sel.annotation.set_text(labels[sel.target.index]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
labels = 'salut tout le monde comment allez vous ?'.split()

fig, ax = plt.subplots()
X = np.random.randn(len(labels), 2)
points = ax.scatter(X[:, 0], X[:, 1])
cursor = mplcursors.cursor(points)
cursor.connect(
    "add", 
    lambda sel: sel.annotation.set_text(labels[sel.target.index])
)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0
